# %%
# %run ./init

# %%
import random
import uuid

# %%
for i in range(0,streamCount):
    
    fileName = str(uuid.uuid4())
    filePath = sourceLoc+"/"+fileName+".json"
    
    streamEventFile = open(filePath,'w')

    streamEvent = {}
    streamEvent["Color"] = groupCols[random.randint(0,5)]
    streamEvent["value"] = random.randint(6,10)
    
    streamEventFile.write(str(streamEvent))
